# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | xam nua
# Processing Record 2 of the Set 1 | kapaa
# Processing Record 3 of the Set 1 | chokurdakh
# Processing Record 4 of the Set 1 | farafangana
# Processing Record 5 of the Set 1 | ushuaia
# Processing Record 6 of the Set 1 | taolanaro
# Processing Record 7 of the Set 1 | sao jose da coroa grande
# Processing Record 8 of the Set 1 | iralaya
# Processing Record 9 of the Set 1 | radishchevo
# Processing Record 10 of the Set 1 | amderma
# Processing Record 11 of the Set 1 | arraial do cabo
# Processing Record 12 of the Set 1 | port alfred
# Processing Record 13 of the Set 1 | victoria
# Processing Record 14 of the Set 1 | saskylakh
# Processing Record 15 of the Set 1 | naze
# Processing Record 16 of the Set 1 | katsuura
# Processing Record 17 of the Set 1 | fortuna
# Processing Record 18 of the Set 1 | mar del plata
# Processing Record 19 of the Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of the Set 1 | avarua
# Processing Record 21 of the Set 1 | dingle
# Processing Record 22 of the Set 1 | hithadhoo
# Processing Record 23 of the Set 1 | sentyabrskiy
# Processing Record 24 of the Set 1 | quatre cocos
# Processing Record 25 of the Set 1 | punta arenas
# Processing Record 26 of the Set 1 | mataura
# Processing Record 27 of the Set 1 | coquimbo
# Processing Record 28 of the Set 1 | kavaratti
# Processing Record 29 of the Set 1 | gloucester
# Processing Record 30 of the Set 1 | saint-augustin
# Processing Record 31 of the Set 1 | yulara
# Processing Record 32 of the Set 1 | pimentel
# Processing Record 33 of the Set 1 | pacific grove
# Processing Record 34 of the Set 1 | sibolga
# Processing Record 35 of the Set 1 | kruisfontein
# Processing Record 36 of the Set 1 | bambous virieux
# Processing Record 37 of the Set 1 | strezhevoy
# Processing Record 38 of the Set 1 | nikolskoye
# Processing Record 39 of the Set 1 | petatlan
# Processing Record 40 of the Set 1 | ribeira grande
# Processing Record 41 of the Set 1 | jyvaskyla
# Processing Record 42 of the Set 1 | new norfolk
# Processing Record 43 of the Set 1 | hilo
# Processing Record 44 of the Set 1 | wagar
# Processing Record 45 of the Set 1 | yellowknife
# Processing Record 46 of the Set 1 | lagoa
# Processing Record 47 of the Set 1 | san quintin
# Processing Record 48 of the Set 1 | touros
# Processing Record 49 of the Set 1 | castelo do piaui
# Processing Record 50 of the Set 1 | provideniya
# Processing Record 1 of the Set 2 | ust-ilimsk
# Processing Record 2 of the Set 2 | ibra
# Processing Record 3 of the Set 2 | albany
# Processing Record 4 of the Set 2 | hobart
# Processing Record 5 of the Set 2 | codrington
# Processing Record 6 of the Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of the Set 2 | cabo san lucas
# Processing Record 8 of the Set 2 | saint-francois
# Processing Record 9 of the Set 2 | oume
# Processing Record 10 of the Set 2 | srednekolymsk
# Processing Record 11 of the Set 2 | vaini
# Processing Record 12 of the Set 2 | airai
# Processing Record 13 of the Set 2 | bluff
# Processing Record 14 of the Set 2 | curup
# Processing Record 15 of the Set 2 | upernavik
# City not found. Skipping...
# Processing Record 16 of the Set 2 | luderitz
# Processing Record 17 of the Set 2 | snasa
# Processing Record 18 of the Set 2 | moses lake
# Processing Record 19 of the Set 2 | aklavik
# Processing Record 20 of the Set 2 | beyneu
# City not found. Skipping...
# Processing Record 21 of the Set 2 | yuanping
# Processing Record 22 of the Set 2 | norman wells
# Processing Record 23 of the Set 2 | busselton
# Processing Record 24 of the Set 2 | noumea
# Processing Record 25 of the Set 2 | cape town
# Processing Record 26 of the Set 2 | puerto ayora
# Processing Record 27 of the Set 2 | egvekinot
# Processing Record 28 of the Set 2 | makakilo city
# Processing Record 29 of the Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of the Set 2 | laguna
# Processing Record 31 of the Set 2 | rikitea
# Processing Record 32 of the Set 2 | hervey bay
# Processing Record 33 of the Set 2 | mount gambier
# Processing Record 34 of the Set 2 | qaanaaq
# City not found. Skipping...
# Processing Record 35 of the Set 2 | haimen
# Processing Record 36 of the Set 2 | port elizabeth
# Processing Record 37 of the Set 2 | port huron
# Processing Record 38 of the Set 2 | silver city
# Processing Record 39 of the Set 2 | mogadishu
# Processing Record 40 of the Set 2 | guerrero negro
# Processing Record 41 of the Set 2 | ljungby
# Processing Record 42 of the Set 2 | tuktoyaktuk
# Processing Record 43 of the Set 2 | kavieng
# Processing Record 44 of the Set 2 | hihifo
# Processing Record 45 of the Set 2 | wajima
# Processing Record 46 of the Set 2 | uozu
# Processing Record 47 of the Set 2 | shimoda
# Processing Record 48 of the Set 2 | severo-kurilsk
# Processing Record 49 of the Set 2 | attawapiskat
# Processing Record 50 of the Set 2 | bengkulu
# Processing Record 1 of the Set 3 | san jeronimo
# Processing Record 2 of the Set 3 | slave lake
# Processing Record 3 of the Set 3 | saurimo
# Processing Record 4 of the Set 3 | udachnyy
# Processing Record 5 of the Set 3 | dublin
# Processing Record 6 of the Set 3 | figeac
# Processing Record 7 of the Set 3 | atuona
# Processing Record 8 of the Set 3 | poum
# Processing Record 9 of the Set 3 | kushima
# Processing Record 10 of the Set 3 | robertsport
# Processing Record 11 of the Set 3 | lavrentiya
# Processing Record 12 of the Set 3 | malakal
# Processing Record 13 of the Set 3 | zavodouspenskoye
# Processing Record 14 of the Set 3 | palakkad
# Processing Record 15 of the Set 3 | pathein
# Processing Record 16 of the Set 3 | khatanga
# Processing Record 17 of the Set 3 | florence
# Processing Record 18 of the Set 3 | richards bay
# Processing Record 19 of the Set 3 | san juan
# Processing Record 20 of the Set 3 | ixtapa
# Processing Record 21 of the Set 3 | jamestown
# Processing Record 22 of the Set 3 | lashio
# Processing Record 23 of the Set 3 | butaritari
# Processing Record 24 of the Set 3 | grindavik
# City not found. Skipping...
# Processing Record 25 of the Set 3 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 26 of the Set 3 | pangkalanbuun
# Processing Record 27 of the Set 3 | mayumba
# Processing Record 28 of the Set 3 | garowe
# Processing Record 29 of the Set 3 | mata
# Processing Record 30 of the Set 3 | tasiilaq
# City not found. Skipping...
# Processing Record 31 of the Set 3 | northam
# Processing Record 32 of the Set 3 | kaitangata
# Processing Record 33 of the Set 3 | hobyo
# Processing Record 34 of the Set 3 | fergus falls
# Processing Record 35 of the Set 3 | arman
# Processing Record 36 of the Set 3 | samusu
# City not found. Skipping...
# Processing Record 37 of the Set 3 | santa cruz
# Processing Record 38 of the Set 3 | visnes
# Processing Record 39 of the Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of the Set 3 | pemangkat
# Processing Record 41 of the Set 3 | alvorada
# Processing Record 42 of the Set 3 | iqaluit
# Processing Record 43 of the Set 3 | barrow
# Processing Record 44 of the Set 3 | houston
# Processing Record 45 of the Set 3 | ucluelet
# Processing Record 46 of the Set 3 | kanniyakumari
# Processing Record 47 of the Set 3 | chicama
# Processing Record 48 of the Set 3 | cayenne
# Processing Record 49 of the Set 3 | payakumbuh
# Processing Record 50 of the Set 3 | vila velha
# Processing Record 1 of the Set 4 | cherskiy
# Processing Record 2 of the Set 4 | ugoofaaru
# Processing Record 3 of the Set 4 | buraydah
# Processing Record 4 of the Set 4 | hermanus
# Processing Record 5 of the Set 4 | rocha
# Processing Record 6 of the Set 4 | matara
# Processing Record 7 of the Set 4 | belushya guba
# Processing Record 8 of the Set 4 | kuminskiy
# Processing Record 9 of the Set 4 | dongsheng
# Processing Record 10 of the Set 4 | palasa
# Processing Record 11 of the Set 4 | lafiagi
# Processing Record 12 of the Set 4 | georgetown
# Processing Record 13 of the Set 4 | saint-philippe
# Processing Record 14 of the Set 4 | bredasdorp
# Processing Record 15 of the Set 4 | lebu
# Processing Record 16 of the Set 4 | nongan
# Processing Record 17 of the Set 4 | faanui
# Processing Record 18 of the Set 4 | hamilton
# Processing Record 19 of the Set 4 | baykit
# Processing Record 20 of the Set 4 | clyde river
# Processing Record 21 of the Set 4 | rapid valley
# Processing Record 22 of the Set 4 | havoysund
# Processing Record 23 of the Set 4 | tiksi
# Processing Record 24 of the Set 4 | south river
# Processing Record 25 of the Set 4 | east london
# Processing Record 26 of the Set 4 | uvat
# Processing Record 27 of the Set 4 | carnarvon
# Processing Record 28 of the Set 4 | mudu
# Processing Record 29 of the Set 4 | saleaula
# City not found. Skipping...
# Processing Record 30 of the Set 4 | aguimes
# Processing Record 31 of the Set 4 | mehamn
# Processing Record 32 of the Set 4 | goderich
# Processing Record 33 of the Set 4 | coahuayana
# Processing Record 34 of the Set 4 | ombessa
# Processing Record 35 of the Set 4 | constitucion
# Processing Record 36 of the Set 4 | watsa
# Processing Record 37 of the Set 4 | alofi
# Processing Record 38 of the Set 4 | hasaki
# Processing Record 39 of the Set 4 | bethel
# Processing Record 40 of the Set 4 | beloha
# Processing Record 41 of the Set 4 | flinders
# Processing Record 42 of the Set 4 | the pas
# Processing Record 43 of the Set 4 | lima
# Processing Record 44 of the Set 4 | vieques
# Processing Record 45 of the Set 4 | sedalia
# Processing Record 46 of the Set 4 | andenes
# Processing Record 47 of the Set 4 | lompoc
# Processing Record 48 of the Set 4 | ilulissat
# City not found. Skipping...
# Processing Record 49 of the Set 4 | latung
# Processing Record 50 of the Set 4 | odda
# Processing Record 1 of the Set 5 | sur
# Processing Record 2 of the Set 5 | makung
# City not found. Skipping...
# Processing Record 3 of the Set 5 | chirongui
# Processing Record 4 of the Set 5 | gizo
# Processing Record 5 of the Set 5 | morros
# Processing Record 6 of the Set 5 | klaksvik
# Processing Record 7 of the Set 5 | illela
# Processing Record 8 of the Set 5 | haines junction
# Processing Record 9 of the Set 5 | araouane
# Processing Record 10 of the Set 5 | cidreira
# Processing Record 11 of the Set 5 | homer
# Processing Record 12 of the Set 5 | kankan
# Processing Record 13 of the Set 5 | hambantota
# Processing Record 14 of the Set 5 | tabas
# Processing Record 15 of the Set 5 | pangnirtung
# Processing Record 16 of the Set 5 | yarada
# Processing Record 17 of the Set 5 | thompson
# Processing Record 18 of the Set 5 | calamar
# Processing Record 19 of the Set 5 | pisco
# Processing Record 20 of the Set 5 | moissala
# Processing Record 21 of the Set 5 | sao filipe
# Processing Record 22 of the Set 5 | khonuu
# Processing Record 23 of the Set 5 | gigmoto
# Processing Record 24 of the Set 5 | souillac
# Processing Record 25 of the Set 5 | salalah
# Processing Record 26 of the Set 5 | castro
# Processing Record 27 of the Set 5 | buenaventura
# Processing Record 28 of the Set 5 | rudbar
# Processing Record 29 of the Set 5 | banda aceh
# Processing Record 30 of the Set 5 | nguiu
# Processing Record 31 of the Set 5 | vardo
# Processing Record 32 of the Set 5 | norwich
# Processing Record 33 of the Set 5 | hay river
# Processing Record 34 of the Set 5 | pevek
# Processing Record 35 of the Set 5 | camacha
# Processing Record 36 of the Set 5 | mount isa
# Processing Record 37 of the Set 5 | kalabo
# Processing Record 38 of the Set 5 | dikson
# Processing Record 39 of the Set 5 | puri
# Processing Record 40 of the Set 5 | fare
# Processing Record 41 of the Set 5 | yokadouma
# Processing Record 42 of the Set 5 | te anau
# Processing Record 43 of the Set 5 | say
# Processing Record 44 of the Set 5 | shelburne
# Processing Record 45 of the Set 5 | belmonte
# Processing Record 46 of the Set 5 | esperance
# Processing Record 47 of the Set 5 | padang
# Processing Record 48 of the Set 5 | sola
# Processing Record 49 of the Set 5 | springbok
# Processing Record 50 of the Set 5 | monrovia
# Processing Record 1 of the Set 6 | narsaq
# City not found. Skipping...
# Processing Record 2 of the Set 6 | aasiaat
# City not found. Skipping...
# Processing Record 3 of the Set 6 | necochea
# Processing Record 4 of the Set 6 | saint george
# Processing Record 5 of the Set 6 | saint-georges
# Processing Record 6 of the Set 6 | sayyan
# Processing Record 7 of the Set 6 | kyaikkami
# Processing Record 8 of the Set 6 | pitimbu
# Processing Record 9 of the Set 6 | milledgeville
# Processing Record 10 of the Set 6 | hualmay
# Processing Record 11 of the Set 6 | bubaque
# Processing Record 12 of the Set 6 | yankton
# Processing Record 13 of the Set 6 | ponta do sol
# Processing Record 14 of the Set 6 | banyuwangi
# Processing Record 15 of the Set 6 | moshi
# Processing Record 16 of the Set 6 | port blair
# Processing Record 17 of the Set 6 | ostrovnoy
# Processing Record 18 of the Set 6 | mizdah
# Processing Record 19 of the Set 6 | bilibino
# Processing Record 20 of the Set 6 | semme
# Processing Record 21 of the Set 6 | keelung
# City not found. Skipping...
# Processing Record 22 of the Set 6 | avera
# Processing Record 23 of the Set 6 | bronnoysund
# Processing Record 24 of the Set 6 | codajas
# Processing Record 25 of the Set 6 | sitka
# Processing Record 26 of the Set 6 | ribeira brava
# Processing Record 27 of the Set 6 | olafsvik
# City not found. Skipping...
# Processing Record 28 of the Set 6 | novo aripuana
# Processing Record 29 of the Set 6 | portland
# Processing Record 30 of the Set 6 | seoul
# Processing Record 31 of the Set 6 | toora-khem
# Processing Record 32 of the Set 6 | camacupa
# Processing Record 33 of the Set 6 | honningsvag
# Processing Record 34 of the Set 6 | kocsord
# Processing Record 35 of the Set 6 | santa isabel do rio negro
# Processing Record 36 of the Set 6 | port augusta
# Processing Record 37 of the Set 6 | tabat
# Processing Record 38 of the Set 6 | namibe
# Processing Record 39 of the Set 6 | kunashak
# Processing Record 40 of the Set 6 | emerald
# Processing Record 41 of the Set 6 | eyrarbakki
# City not found. Skipping...
# Processing Record 42 of the Set 6 | port lincoln
# Processing Record 43 of the Set 6 | krasnoselkup
# Processing Record 44 of the Set 6 | liverpool
# Processing Record 45 of the Set 6 | saint-joseph
# Processing Record 46 of the Set 6 | qaqortoq
# City not found. Skipping...
# Processing Record 47 of the Set 6 | morondava
# Processing Record 48 of the Set 6 | kodiak
# Processing Record 49 of the Set 6 | verkhovye
# Processing Record 50 of the Set 6 | longyearbyen
# City not found. Skipping...
# Processing Record 1 of the Set 7 | newport
# Processing Record 2 of the Set 7 | kangaatsiaq
# City not found. Skipping...
# Processing Record 3 of the Set 7 | hami
# Processing Record 4 of the Set 7 | lebyazhye
# Processing Record 5 of the Set 7 | ahuimanu
# Processing Record 6 of the Set 7 | vangaindrano
# Processing Record 7 of the Set 7 | yamada
# Processing Record 8 of the Set 7 | tidore
# Processing Record 9 of the Set 7 | mys shmidta
# Processing Record 10 of the Set 7 | basco
# Processing Record 11 of the Set 7 | geraldton
# Processing Record 12 of the Set 7 | umzimvubu
# Processing Record 13 of the Set 7 | libenge
# Processing Record 14 of the Set 7 | mushie
# Processing Record 15 of the Set 7 | bouza
# Processing Record 16 of the Set 7 | guabito
# Processing Record 17 of the Set 7 | worland
# Processing Record 18 of the Set 7 | sangar
# Processing Record 19 of the Set 7 | qom
# Processing Record 20 of the Set 7 | manta
# Processing Record 21 of the Set 7 | yangambi
# Processing Record 22 of the Set 7 | sao sepe
# Processing Record 23 of the Set 7 | vallenar
# Processing Record 24 of the Set 7 | hendijan
# Processing Record 25 of the Set 7 | palora
# Processing Record 26 of the Set 7 | tombouctou
# Processing Record 27 of the Set 7 | sicuani
# Processing Record 28 of the Set 7 | flin flon
# Processing Record 29 of the Set 7 | natal
# Processing Record 30 of the Set 7 | labuhan
# Processing Record 31 of the Set 7 | alice springs
# Processing Record 32 of the Set 7 | nador
# Processing Record 33 of the Set 7 | ust-kamchatsk
# Processing Record 34 of the Set 7 | tulun
# Processing Record 35 of the Set 7 | husavik
# City not found. Skipping...
# Processing Record 36 of the Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of the Set 7 | nizhneyansk
# Processing Record 38 of the Set 7 | vincennes
# Processing Record 39 of the Set 7 | boshkengash
# Processing Record 40 of the Set 7 | carauari
# Processing Record 41 of the Set 7 | cobija
# Processing Record 42 of the Set 7 | messina
# Processing Record 43 of the Set 7 | zabaykalsk
# Processing Record 44 of the Set 7 | ayan
# Processing Record 45 of the Set 7 | nanortalik
# Processing Record 46 of the Set 7 | pochutla
# Processing Record 47 of the Set 7 | lahad datu
# Processing Record 48 of the Set 7 | nome
# Processing Record 49 of the Set 7 | tambopata
# Processing Record 50 of the Set 7 | kutum
# Processing Record 1 of the Set 8 | taltal
# Processing Record 2 of the Set 8 | mezen
# Processing Record 3 of the Set 8 | malya
# Processing Record 4 of the Set 8 | abaza
# Processing Record 5 of the Set 8 | oktyabrskiy
# Processing Record 6 of the Set 8 | chuy
# Processing Record 7 of the Set 8 | torbay
# Processing Record 8 of the Set 8 | anamur
# Processing Record 9 of the Set 8 | san cristobal
# Processing Record 10 of the Set 8 | xining
# Processing Record 11 of the Set 8 | pilar
# Processing Record 12 of the Set 8 | mrirt
# Processing Record 13 of the Set 8 | kuliyapitiya
# Processing Record 14 of the Set 8 | coracora
# Processing Record 15 of the Set 8 | stamsund
# Processing Record 16 of the Set 8 | gallup
# Processing Record 17 of the Set 8 | balkanabat
# Processing Record 18 of the Set 8 | seddon
# Processing Record 19 of the Set 8 | corn island
# Processing Record 20 of the Set 8 | praia da vitoria
# Processing Record 21 of the Set 8 | conceicao do araguaia
# Processing Record 22 of the Set 8 | huarmey
# Processing Record 23 of the Set 8 | gasa
# Processing Record 24 of the Set 8 | altona
# Processing Record 25 of the Set 8 | leningradskiy
# Processing Record 26 of the Set 8 | stephenville
# Processing Record 27 of the Set 8 | walvis bay
# Processing Record 28 of the Set 8 | bundaberg
# Processing Record 29 of the Set 8 | anadyr
# Processing Record 30 of the Set 8 | nam tha
# Processing Record 31 of the Set 8 | ampanihy
# Processing Record 32 of the Set 8 | szekkutas
# Processing Record 33 of the Set 8 | saint-pierre
# Processing Record 34 of the Set 8 | otradnoye
# Processing Record 35 of the Set 8 | lubartow
# Processing Record 36 of the Set 8 | cape coast
# Processing Record 37 of the Set 8 | nishihara
# Processing Record 38 of the Set 8 | half moon bay
# Processing Record 39 of the Set 8 | hope
# Processing Record 40 of the Set 8 | qui nhon
# Processing Record 41 of the Set 8 | wulanhaote
# Processing Record 42 of the Set 8 | komsomolskiy
# Processing Record 43 of the Set 8 | bathsheba
# Processing Record 44 of the Set 8 | great yarmouth
# Processing Record 45 of the Set 8 | chagda
# Processing Record 46 of the Set 8 | petropavlovsk-kamchatskiy
# Processing Record 47 of the Set 8 | talnakh
# Processing Record 48 of the Set 8 | ocampo
# Processing Record 49 of the Set 8 | chantada
# Processing Record 50 of the Set 8 | kingisepp
# Processing Record 1 of the Set 9 | karratha
# Processing Record 2 of the Set 9 | bhinmal
# Processing Record 3 of the Set 9 | millinocket
# Processing Record 4 of the Set 9 | akdepe
# Processing Record 5 of the Set 9 | nouakchott
# Processing Record 6 of the Set 9 | honiara
# Processing Record 7 of the Set 9 | caravelas
# Processing Record 8 of the Set 9 | saldanha
# Processing Record 9 of the Set 9 | broome
# Processing Record 10 of the Set 9 | mahadday weyne
# Processing Record 11 of the Set 9 | zhigansk
# Processing Record 12 of the Set 9 | bursol
# Processing Record 13 of the Set 9 | ode
# Processing Record 14 of the Set 9 | kedrovyy
# Processing Record 15 of the Set 9 | kahului
# Processing Record 16 of the Set 9 | ruatoria
# Processing Record 17 of the Set 9 | sambava
# Processing Record 18 of the Set 9 | baruun-urt
# Processing Record 19 of the Set 9 | bichura
# Processing Record 20 of the Set 9 | gander
# Processing Record 21 of the Set 9 | diu
# Processing Record 22 of the Set 9 | panaba
# Processing Record 23 of the Set 9 | faya
# Processing Record 24 of the Set 9 | morki
# Processing Record 25 of the Set 9 | ancud
# Processing Record 26 of the Set 9 | sisimiut
# Processing Record 27 of the Set 9 | illapel
# Processing Record 28 of the Set 9 | pangobilian
# Processing Record 29 of the Set 9 | piney green
# Processing Record 30 of the Set 9 | jiupu
# Processing Record 31 of the Set 9 | niteroi
# Processing Record 32 of the Set 9 | port macquarie
# Processing Record 33 of the Set 9 | mareeba
# Processing Record 34 of the Set 9 | shawinigan
# Processing Record 35 of the Set 9 | san patricio
# Processing Record 36 of the Set 9 | vila franca do campo
# Processing Record 37 of the Set 9 | panlaitan
# Processing Record 38 of the Set 9 | ternate
# Processing Record 39 of the Set 9 | amberley
# Processing Record 40 of the Set 9 | la ronge
# Processing Record 41 of the Set 9 | palabuhanratu
# Processing Record 42 of the Set 9 | fairbanks
# Processing Record 43 of the Set 9 | kirkuk
# Processing Record 44 of the Set 9 | tilichiki
# Processing Record 45 of the Set 9 | bambanglipuro
# Processing Record 46 of the Set 9 | senno
# Processing Record 47 of the Set 9 | grand river south east
# Processing Record 48 of the Set 9 | vilhena
# Processing Record 49 of the Set 9 | kamenka
# Processing Record 50 of the Set 9 | maarianhamina
# Processing Record 1 of the Set 10 | yuxia
# Processing Record 2 of the Set 10 | mopti
# Processing Record 3 of the Set 10 | hilpoltstein
# Processing Record 4 of the Set 10 | huoqiu
# Processing Record 5 of the Set 10 | mwinilunga
# Processing Record 6 of the Set 10 | khandyga
# Processing Record 7 of the Set 10 | manono
# Processing Record 8 of the Set 10 | mirnyy
# Processing Record 9 of the Set 10 | wadowice
# Processing Record 10 of the Set 10 | rungata
# Processing Record 11 of the Set 10 | isangel
# Processing Record 12 of the Set 10 | peace river
# Processing Record 13 of the Set 10 | dunedin
# Processing Record 14 of the Set 10 | ariquemes
# Processing Record 15 of the Set 10 | bafata
# Processing Record 16 of the Set 10 | juneau
# Processing Record 17 of the Set 10 | zyryanovsk
# Processing Record 18 of the Set 10 | deniliquin
# Processing Record 19 of the Set 10 | nabire
# Processing Record 20 of the Set 10 | roald
# Processing Record 21 of the Set 10 | san jose
# Processing Record 22 of the Set 10 | nara
# Processing Record 23 of the Set 10 | kouango
# Processing Record 24 of the Set 10 | kampong thum
# Processing Record 25 of the Set 10 | wewak
# Processing Record 26 of the Set 10 | turukhansk
# Processing Record 27 of the Set 10 | altamira
# Processing Record 28 of the Set 10 | robstown
# Processing Record 29 of the Set 10 | lasa
# Processing Record 30 of the Set 10 | grand centre
# Processing Record 31 of the Set 10 | tecpan
# Processing Record 32 of the Set 10 | roma
# Processing Record 33 of the Set 10 | meulaboh
# Processing Record 34 of the Set 10 | hofn
# Processing Record 35 of the Set 10 | pustoshka
# Processing Record 36 of the Set 10 | marzuq
# Processing Record 37 of the Set 10 | kautokeino
# Processing Record 38 of the Set 10 | linchuan
# Processing Record 39 of the Set 10 | worthington
# Processing Record 40 of the Set 10 | otane
# Processing Record 41 of the Set 10 | magomeni
# Processing Record 42 of the Set 10 | killybegs
# Processing Record 43 of the Set 10 | mahebourg
# Processing Record 44 of the Set 10 | san rafael
# Processing Record 45 of the Set 10 | ust-kuyga
# Processing Record 46 of the Set 10 | general roca
# Processing Record 47 of the Set 10 | porto walter
# Processing Record 48 of the Set 10 | coruripe
# Processing Record 49 of the Set 10 | victor harbor
# Processing Record 50 of the Set 10 | mairana
# Processing Record 1 of the Set 11 | sembe
# Processing Record 2 of the Set 11 | port hedland
# Processing Record 3 of the Set 11 | boli
# Processing Record 4 of the Set 11 | diffa
# Processing Record 5 of the Set 11 | lorengau
# Processing Record 6 of the Set 11 | kotma
# Processing Record 7 of the Set 11 | sutysky
# Processing Record 8 of the Set 11 | opuwo
# Processing Record 9 of the Set 11 | riyadh
# Processing Record 10 of the Set 11 | tumannyy
# Processing Record 11 of the Set 11 | erzurum
# Processing Record 12 of the Set 11 | la solana
# Processing Record 13 of the Set 11 | tual
# Processing Record 14 of the Set 11 | ilorin
# Processing Record 15 of the Set 11 | ekhabi
# Processing Record 16 of the Set 11 | caconda
# Processing Record 17 of the Set 11 | gweta
# Processing Record 18 of the Set 11 | mayskiy
# Processing Record 19 of the Set 11 | birao
# Processing Record 20 of the Set 11 | progreso
# Processing Record 21 of the Set 11 | datong
# Processing Record 22 of the Set 11 | buala
# Processing Record 23 of the Set 11 | porto novo
# Processing Record 24 of the Set 11 | medeiros neto
# Processing Record 25 of the Set 11 | lata
# Processing Record 26 of the Set 11 | tuatapere
# Processing Record 27 of the Set 11 | tigil
# Processing Record 28 of the Set 11 | axim
# Processing Record 29 of the Set 11 | mayo
# Processing Record 30 of the Set 11 | benguela
# Processing Record 31 of the Set 11 | kapuskasing
# Processing Record 32 of the Set 11 | karatuzskoye
# Processing Record 33 of the Set 11 | havre-saint-pierre
# Processing Record 34 of the Set 11 | termoli
# Processing Record 35 of the Set 11 | rize
# Processing Record 36 of the Set 11 | grand-santi
# Processing Record 37 of the Set 11 | waipawa
# Processing Record 38 of the Set 11 | tabou
# Processing Record 39 of the Set 11 | dzerzhinsk
# Processing Record 40 of the Set 11 | santa isabel
# Processing Record 41 of the Set 11 | auch
# Processing Record 42 of the Set 11 | ishigaki
# Processing Record 43 of the Set 11 | ban nahin
# Processing Record 44 of the Set 11 | wahran
# City not found. Skipping...
# Processing Record 45 of the Set 11 | minna
# Processing Record 46 of the Set 11 | erzin
# Processing Record 47 of the Set 11 | ilinogorsk
# Processing Record 48 of the Set 11 | fort saint john
# Processing Record 49 of the Set 11 | iskateley
# Processing Record 50 of the Set 11 | abu samrah
# Processing Record 1 of the Set 12 | rondonopolis
# Processing Record 2 of the Set 12 | fourmies
# Processing Record 3 of the Set 12 | ambilobe
# Processing Record 4 of the Set 12 | la libertad
# Processing Record 5 of the Set 12 | zachary
# Processing Record 6 of the Set 12 | nizhnyaya salda
# Processing Record 7 of the Set 12 | vila
# Processing Record 8 of the Set 12 | mbeya
# Processing Record 9 of the Set 12 | nuuk
# Processing Record 10 of the Set 12 | imbituba
# Processing Record 11 of the Set 12 | oblesevo
# Processing Record 12 of the Set 12 | channel-port aux basques
# Processing Record 13 of the Set 12 | bairiki
# Processing Record 14 of the Set 12 | yar-sale
# Processing Record 15 of the Set 12 | puerto escondido
# Processing Record 16 of the Set 12 | neiafu
# Processing Record 17 of the Set 12 | alotau
# Processing Record 18 of the Set 12 | gobabis
# Processing Record 19 of the Set 12 | graaff-reinet
# Processing Record 20 of the Set 12 | vanavara
# Processing Record 21 of the Set 12 | redcliffe
# Processing Record 22 of the Set 12 | kupang
# Processing Record 23 of the Set 12 | lagos
# Processing Record 24 of the Set 12 | lumphat
# Processing Record 25 of the Set 12 | soe
# Processing Record 26 of the Set 12 | marakkanam
# Processing Record 27 of the Set 12 | madang
# Processing Record 28 of the Set 12 | locri
# Processing Record 29 of the Set 12 | marystown
# Processing Record 30 of the Set 12 | valdepenas
# Processing Record 31 of the Set 12 | berlevag
# Processing Record 32 of the Set 12 | muzhi
# Processing Record 33 of the Set 12 | kidal
# Processing Record 34 of the Set 12 | asfi
# Processing Record 35 of the Set 12 | uchiza
# Processing Record 36 of the Set 12 | wahpeton
# Processing Record 37 of the Set 12 | tura
# Processing Record 38 of the Set 12 | jesi
# Processing Record 39 of the Set 12 | anori
# Processing Record 40 of the Set 12 | bonthe
# Processing Record 41 of the Set 12 | acapulco
# Processing Record 42 of the Set 12 | manokwari
# Processing Record 43 of the Set 12 | jiuquan
# Processing Record 44 of the Set 12 | thaton
# Processing Record 45 of the Set 12 | soloneshnoye
# Processing Record 46 of the Set 12 | armacao dos buzios
# Processing Record 47 of the Set 12 | palmares do sul
# Processing Record 48 of the Set 12 | mercedes
# Processing Record 49 of the Set 12 | peniche
# Processing Record 50 of the Set 12 | dehui
# Processing Record 1 of the Set 13 | dawei
# Processing Record 2 of the Set 13 | lethem
# Processing Record 3 of the Set 13 | kirensk
# Processing Record 4 of the Set 13 | guadalupe y calvo
# Processing Record 5 of the Set 13 | plouzane
# Processing Record 6 of the Set 13 | artyk
# Processing Record 7 of the Set 13 | zhanatas
# Processing Record 8 of the Set 13 | payo
# Processing Record 9 of the Set 13 | acarau
# Processing Record 10 of the Set 13 | phan rang
# Processing Record 11 of the Set 13 | gazli
# Processing Record 12 of the Set 13 | longlac
# Processing Record 13 of the Set 13 | russell
# Processing Record 14 of the Set 13 | xai-xai
# Processing Record 15 of the Set 13 | bonavista
# Processing Record 16 of the Set 13 | rochegda
# Processing Record 17 of the Set 13 | waingapu
# Processing Record 18 of the Set 13 | deputatskiy
# Processing Record 19 of the Set 13 | claremont
# Processing Record 20 of the Set 13 | kaeo
# Processing Record 21 of the Set 13 | saint-leu
# Processing Record 22 of the Set 13 | graham
# Processing Record 23 of the Set 13 | roebourne
# Processing Record 24 of the Set 13 | patan
# Processing Record 25 of the Set 13 | eureka
# Processing Record 26 of the Set 13 | barkhan
# Processing Record 27 of the Set 13 | lyman
# Processing Record 28 of the Set 13 | taburi
# Processing Record 29 of the Set 13 | auki
# Processing Record 30 of the Set 13 | barrhead
# Processing Record 31 of the Set 13 | korla
# Processing Record 32 of the Set 13 | iracoubo
# Processing Record 33 of the Set 13 | ribas do rio pardo
# Processing Record 34 of the Set 13 | saint-pierre
# Processing Record 35 of the Set 13 | okato
# Processing Record 36 of the Set 13 | eregli
# Processing Record 37 of the Set 13 | tsihombe
# Processing Record 38 of the Set 13 | takoradi
# Processing Record 39 of the Set 13 | karpuninskiy
# Processing Record 40 of the Set 13 | saint anthony
# Processing Record 41 of the Set 13 | nouadhibou
# Processing Record 42 of the Set 13 | katherine
# Processing Record 43 of the Set 13 | whitehorse
# Processing Record 44 of the Set 13 | mamallapuram
# Processing Record 45 of the Set 13 | sobradinho
# Processing Record 46 of the Set 13 | sept-iles
# Processing Record 47 of the Set 13 | mwene-ditu
# Processing Record 48 of the Set 13 | ilinge
# Processing Record 49 of the Set 13 | college
# Processing Record 50 of the Set 13 | cherdyn
# Processing Record 1 of the Set 14 | freeport
# Processing Record 2 of the Set 14 | rio gallegos
# Processing Record 3 of the Set 14 | kloulklubed
# Processing Record 4 of the Set 14 | tkvarcheli
# City not found. Skipping...
# Processing Record 5 of the Set 14 | sinnamary
# Processing Record 6 of the Set 14 | shingu
# Processing Record 7 of the Set 14 | manicore
# Processing Record 8 of the Set 14 | taoudenni
# Processing Record 9 of the Set 14 | ereymentau
# Processing Record 10 of the Set 14 | xuanwu
# Processing Record 11 of the Set 14 | pueblo nuevo
# Processing Record 12 of the Set 14 | tsienyane
# Processing Record 13 of the Set 14 | pena
# Processing Record 14 of the Set 14 | santa maria
# Processing Record 15 of the Set 14 | fuente palmera
# Processing Record 16 of the Set 14 | natchitoches
# Processing Record 17 of the Set 14 | bur gabo
# Processing Record 18 of the Set 14 | kusti
# Processing Record 19 of the Set 14 | margate
# Processing Record 20 of the Set 14 | nizhniy tsasuchey
# Processing Record 21 of the Set 14 | ginda
# Processing Record 22 of the Set 14 | tabialan
# Processing Record 23 of the Set 14 | kuche
# Processing Record 24 of the Set 14 | dwarka
# Processing Record 25 of the Set 14 | la palma
# Processing Record 26 of the Set 14 | glendive
# Processing Record 27 of the Set 14 | safonovo
# Processing Record 28 of the Set 14 | havelock
# Processing Record 29 of the Set 14 | tautira
# Processing Record 30 of the Set 14 | turbat
# Processing Record 31 of the Set 14 | bafoulabe
# Processing Record 32 of the Set 14 | winneba
# Processing Record 33 of the Set 14 | kapit
# Processing Record 34 of the Set 14 | anar darreh
# Processing Record 35 of the Set 14 | broken hill
# Processing Record 36 of the Set 14 | chazuta
# Processing Record 37 of the Set 14 | angoche
# Processing Record 38 of the Set 14 | kovrov
# Processing Record 39 of the Set 14 | kurumkan
# Processing Record 40 of the Set 14 | luanda
# Processing Record 41 of the Set 14 | nileshwar
# Processing Record 42 of the Set 14 | abnub
# Processing Record 43 of the Set 14 | ratnagiri
# Processing Record 44 of the Set 14 | keetmanshoop
# Processing Record 45 of the Set 14 | tukrah
# Processing Record 46 of the Set 14 | nizip
# Processing Record 47 of the Set 14 | santa rosa
# Processing Record 48 of the Set 14 | meyungs
# Processing Record 49 of the Set 14 | koratagere
# Processing Record 50 of the Set 14 | urk
# Processing Record 1 of the Set 15 | martil
# Processing Record 2 of the Set 15 | ginir
# Processing Record 3 of the Set 15 | agadez
# Processing Record 4 of the Set 15 | valle hermoso
# Processing Record 5 of the Set 15 | poya
# Processing Record 6 of the Set 15 | bayangol
# Processing Record 7 of the Set 15 | billings
# Processing Record 8 of the Set 15 | tabursuq
# Processing Record 9 of the Set 15 | djambala
# Processing Record 10 of the Set 15 | fairhope
# Processing Record 11 of the Set 15 | pahrump
# Processing Record 12 of the Set 15 | kumluca
# Processing Record 13 of the Set 15 | bilma
# Processing Record 14 of the Set 15 | poli
# Processing Record 15 of the Set 15 | samana
# Processing Record 16 of the Set 15 | alibunan
# Processing Record 17 of the Set 15 | panagjuriste
# City not found. Skipping...
# Processing Record 18 of the Set 15 | jishou
# Processing Record 19 of the Set 15 | colchester
# Processing Record 20 of the Set 15 | terracina
# Processing Record 21 of the Set 15 | charters towers
# Processing Record 22 of the Set 15 | nhulunbuy
# Processing Record 23 of the Set 15 | lebork
# Processing Record 24 of the Set 15 | halmstad
# Processing Record 25 of the Set 15 | okhotsk
# Processing Record 26 of the Set 15 | cascais
# Processing Record 27 of the Set 15 | jandiala
# Processing Record 28 of the Set 15 | coihaique
# Processing Record 29 of the Set 15 | azimur
# Processing Record 30 of the Set 15 | campoverde
# Processing Record 31 of the Set 15 | eenhana
# Processing Record 32 of the Set 15 | tshikapa
# Processing Record 33 of the Set 15 | arlit
# Processing Record 34 of the Set 15 | samarai
# Processing Record 35 of the Set 15 | zaozerne
# Processing Record 36 of the Set 15 | san andres
# Processing Record 37 of the Set 15 | alyangula
# Processing Record 38 of the Set 15 | estelle
# Processing Record 39 of the Set 15 | wasilla
# Processing Record 40 of the Set 15 | plettenberg bay
# Processing Record 41 of the Set 15 | tyazhinskiy
# Processing Record 42 of the Set 15 | fayaoue
# Processing Record 43 of the Set 15 | bluefield
# Processing Record 44 of the Set 15 | teahupoo
# Processing Record 45 of the Set 15 | marsaxlokk
# Processing Record 46 of the Set 15 | staffanstorp
# Processing Record 47 of the Set 15 | liyang
# Processing Record 48 of the Set 15 | bargal
# Processing Record 49 of the Set 15 | grand gaube
# Processing Record 50 of the Set 15 | buqayq
# Processing Record 1 of the Set 16 | raudeberg
# Processing Record 2 of the Set 16 | zaporizhzhya
# Processing Record 3 of the Set 16 | kununurra
# Processing Record 4 of the Set 16 | mastic beach
# Processing Record 5 of the Set 16 | amga
# Processing Record 6 of the Set 16 | oum hadjer
# Processing Record 7 of the Set 16 | kigoma
# Processing Record 8 of the Set 16 | gorkovskoye
# Processing Record 9 of the Set 16 | las piedras
# Processing Record 10 of the Set 16 | vozhega
# Processing Record 11 of the Set 16 | sampit
# Processing Record 12 of the Set 16 | dudinka
# Processing Record 13 of the Set 16 | villamontes
# Processing Record 14 of the Set 16 | hirado
# Processing Record 15 of the Set 16 | arona
# Processing Record 16 of the Set 16 | kumo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check number of cities in the dataframe
len(city_data)
# Out:
# 739

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Xam Nua      LA  20.4197  104.0439     83.82        31          44
# 1        Kapaa      US  22.0752 -159.3190     74.66        71          98
# 2   Chokurdakh      RU  70.6333  147.9167     -5.35        96          98
# 3  Farafangana      MG -22.8167   47.8333     76.96        83          35
# 4      Ushuaia      AR -54.8000  -68.3000     46.06        53          75
#
#    Wind Speed Current Description
# 0        1.32    scattered clouds
# 1        3.13     overcast clouds
# 2        5.86     overcast clouds
# 3        1.70    scattered clouds
# 4       23.02       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
