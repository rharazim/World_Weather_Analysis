# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
len(cities)
# Out:
# 766

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | cape town
# Processing Record 2 of the Set 1 | havelock
# Processing Record 3 of the Set 1 | touros
# Processing Record 4 of the Set 1 | provideniya
# Processing Record 5 of the Set 1 | tillabery
# City not found. Skipping...
# Processing Record 6 of the Set 1 | ushuaia
# Processing Record 7 of the Set 1 | aklavik
# Processing Record 8 of the Set 1 | klaksvik
# Processing Record 9 of the Set 1 | hilo
# Processing Record 10 of the Set 1 | araouane
# Processing Record 11 of the Set 1 | marsa matruh
# Processing Record 12 of the Set 1 | jamestown
# Processing Record 13 of the Set 1 | rikitea
# Processing Record 14 of the Set 1 | kodiak
# Processing Record 15 of the Set 1 | thompson
# Processing Record 16 of the Set 1 | rio grande
# Processing Record 17 of the Set 1 | mandalgovi
# Processing Record 18 of the Set 1 | atuona
# Processing Record 19 of the Set 1 | korla
# Processing Record 20 of the Set 1 | lagoa
# Processing Record 21 of the Set 1 | grand-santi
# Processing Record 22 of the Set 1 | carnarvon
# Processing Record 23 of the Set 1 | kizema
# Processing Record 24 of the Set 1 | hithadhoo
# Processing Record 25 of the Set 1 | hasaki
# Processing Record 26 of the Set 1 | nkhata bay
# Processing Record 27 of the Set 1 | dillon
# Processing Record 28 of the Set 1 | krasnovishersk
# Processing Record 29 of the Set 1 | punta arenas
# Processing Record 30 of the Set 1 | albanel
# Processing Record 31 of the Set 1 | guanica
# Processing Record 32 of the Set 1 | pangnirtung
# Processing Record 33 of the Set 1 | bredasdorp
# Processing Record 34 of the Set 1 | sidi ali
# Processing Record 35 of the Set 1 | port hawkesbury
# Processing Record 36 of the Set 1 | mys shmidta
# Processing Record 37 of the Set 1 | avarua
# Processing Record 38 of the Set 1 | verkhoyansk
# Processing Record 39 of the Set 1 | ponnampet
# Processing Record 40 of the Set 1 | hobart
# Processing Record 41 of the Set 1 | talnakh
# Processing Record 42 of the Set 1 | aswan
# Processing Record 43 of the Set 1 | miles city
# Processing Record 44 of the Set 1 | busselton
# Processing Record 45 of the Set 1 | saint george
# Processing Record 46 of the Set 1 | bisho
# Processing Record 47 of the Set 1 | tosya
# Processing Record 48 of the Set 1 | sao mateus do maranhao
# Processing Record 49 of the Set 1 | domoni
# Processing Record 50 of the Set 1 | khash
# Processing Record 1 of the Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of the Set 2 | bandarbeyla
# Processing Record 3 of the Set 2 | armacao dos buzios
# Processing Record 4 of the Set 2 | hermanus
# Processing Record 5 of the Set 2 | kazbegi
# City not found. Skipping...
# Processing Record 6 of the Set 2 | sitka
# Processing Record 7 of the Set 2 | bayeux
# Processing Record 8 of the Set 2 | albany
# Processing Record 9 of the Set 2 | amderma
# Processing Record 10 of the Set 2 | coihaique
# Processing Record 11 of the Set 2 | mataura
# Processing Record 12 of the Set 2 | bluff
# Processing Record 13 of the Set 2 | richards bay
# Processing Record 14 of the Set 2 | rocha
# Processing Record 15 of the Set 2 | yellowknife
# Processing Record 16 of the Set 2 | georgetown
# Processing Record 17 of the Set 2 | ganzhou
# Processing Record 18 of the Set 2 | paradwip
# Processing Record 19 of the Set 2 | kapaa
# Processing Record 20 of the Set 2 | east london
# Processing Record 21 of the Set 2 | port elizabeth
# Processing Record 22 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of the Set 2 | port blair
# Processing Record 24 of the Set 2 | nizhneyansk
# Processing Record 25 of the Set 2 | mar del plata
# Processing Record 26 of the Set 2 | hakkari
# Processing Record 27 of the Set 2 | kadykchan
# Processing Record 28 of the Set 2 | awjilah
# Processing Record 29 of the Set 2 | katsuura
# Processing Record 30 of the Set 2 | mehamn
# Processing Record 31 of the Set 2 | shimoda
# Processing Record 32 of the Set 2 | norman wells
# Processing Record 33 of the Set 2 | koumac
# Processing Record 34 of the Set 2 | ilulissat
# City not found. Skipping...
# Processing Record 35 of the Set 2 | puerto ayora
# Processing Record 36 of the Set 2 | lavrentiya
# Processing Record 37 of the Set 2 | koslan
# Processing Record 38 of the Set 2 | vinstra
# Processing Record 39 of the Set 2 | castro
# Processing Record 40 of the Set 2 | san luis
# Processing Record 41 of the Set 2 | isangel
# Processing Record 42 of the Set 2 | ponta do sol
# Processing Record 43 of the Set 2 | bubaque
# Processing Record 44 of the Set 2 | beringovskiy
# Processing Record 45 of the Set 2 | mount gambier
# Processing Record 46 of the Set 2 | marawi
# Processing Record 47 of the Set 2 | gold coast
# Processing Record 48 of the Set 2 | qaanaaq
# City not found. Skipping...
# Processing Record 49 of the Set 2 | siderno
# Processing Record 50 of the Set 2 | vaini
# Processing Record 1 of the Set 3 | ribeira grande
# Processing Record 2 of the Set 3 | sigiriya
# Processing Record 3 of the Set 3 | shelburne
# Processing Record 4 of the Set 3 | saint-pierre
# Processing Record 5 of the Set 3 | dikson
# Processing Record 6 of the Set 3 | sambava
# City not found. Skipping...
# Processing Record 7 of the Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of the Set 3 | nizhniy baskunchak
# Processing Record 9 of the Set 3 | chahal
# Processing Record 10 of the Set 3 | henties bay
# Processing Record 11 of the Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of the Set 3 | lolua
# City not found. Skipping...
# Processing Record 13 of the Set 3 | phulabani
# Processing Record 14 of the Set 3 | ixtapa
# Processing Record 15 of the Set 3 | mentok
# City not found. Skipping...
# Processing Record 16 of the Set 3 | nanortalik
# City not found. Skipping...
# Processing Record 17 of the Set 3 | faanui
# Processing Record 18 of the Set 3 | merauke
# City not found. Skipping...
# Processing Record 19 of the Set 3 | kralendijk
# Processing Record 20 of the Set 3 | codrington
# Processing Record 21 of the Set 3 | bonavista
# Processing Record 22 of the Set 3 | ponta do sol
# Processing Record 23 of the Set 3 | cayenne
# Processing Record 24 of the Set 3 | vavozh
# Processing Record 25 of the Set 3 | nikolskoye
# Processing Record 26 of the Set 3 | nishiwaki
# Processing Record 27 of the Set 3 | torbay
# Processing Record 28 of the Set 3 | ilhabela
# Processing Record 29 of the Set 3 | khandyga
# Processing Record 30 of the Set 3 | machico
# Processing Record 31 of the Set 3 | florida
# Processing Record 32 of the Set 3 | yasnyy
# Processing Record 33 of the Set 3 | northam
# Processing Record 34 of the Set 3 | mecca
# Processing Record 35 of the Set 3 | barrow
# Processing Record 36 of the Set 3 | khani
# Processing Record 37 of the Set 3 | buraydah
# Processing Record 38 of the Set 3 | ruteng
# City not found. Skipping...
# Processing Record 39 of the Set 3 | kaitangata
# Processing Record 40 of the Set 3 | klyuchi
# Processing Record 41 of the Set 3 | jalu
# Processing Record 42 of the Set 3 | bilibino
# Processing Record 43 of the Set 3 | ancud
# Processing Record 44 of the Set 3 | cidreira
# Processing Record 45 of the Set 3 | butaritari
# Processing Record 46 of the Set 3 | oriximina
# Processing Record 47 of the Set 3 | bay roberts
# Processing Record 48 of the Set 3 | purranque
# Processing Record 49 of the Set 3 | chepareria
# Processing Record 50 of the Set 3 | nago
# Processing Record 1 of the Set 4 | kenai
# Processing Record 2 of the Set 4 | melilla
# Processing Record 3 of the Set 4 | imbituba
# Processing Record 4 of the Set 4 | arraial do cabo
# Processing Record 5 of the Set 4 | cuyo
# Processing Record 6 of the Set 4 | flinders
# Processing Record 7 of the Set 4 | kamenka
# Processing Record 8 of the Set 4 | aracruz
# Processing Record 9 of the Set 4 | winslow
# Processing Record 10 of the Set 4 | ngama
# Processing Record 11 of the Set 4 | plettenberg bay
# Processing Record 12 of the Set 4 | new norfolk
# Processing Record 13 of the Set 4 | upernavik
# City not found. Skipping...
# Processing Record 14 of the Set 4 | vardo
# Processing Record 15 of the Set 4 | penzance
# Processing Record 16 of the Set 4 | margate
# Processing Record 17 of the Set 4 | guerrero negro
# Processing Record 18 of the Set 4 | saint-raymond
# Processing Record 19 of the Set 4 | longyearbyen
# Processing Record 20 of the Set 4 | pevek
# Processing Record 21 of the Set 4 | lumberton
# Processing Record 22 of the Set 4 | anadyr
# Processing Record 23 of the Set 4 | solnechnyy
# Processing Record 24 of the Set 4 | bethel
# Processing Record 25 of the Set 4 | dimbokro
# Processing Record 26 of the Set 4 | san ramon
# Processing Record 27 of the Set 4 | coahuayana
# Processing Record 28 of the Set 4 | alice springs
# Processing Record 29 of the Set 4 | sonari
# Processing Record 30 of the Set 4 | tura
# Processing Record 31 of the Set 4 | taoudenni
# Processing Record 32 of the Set 4 | upata
# Processing Record 33 of the Set 4 | husavik
# Processing Record 34 of the Set 4 | novyy urengoy
# Processing Record 35 of the Set 4 | port lincoln
# Processing Record 36 of the Set 4 | abu dhabi
# Processing Record 37 of the Set 4 | kamenskoye
# Processing Record 38 of the Set 4 | khatanga
# Processing Record 39 of the Set 4 | dafeng
# Processing Record 40 of the Set 4 | akureyri
# Processing Record 41 of the Set 4 | caiaponia
# Processing Record 42 of the Set 4 | tefe
# Processing Record 43 of the Set 4 | lasa
# Processing Record 44 of the Set 4 | revyakino
# Processing Record 45 of the Set 4 | sasina
# Processing Record 46 of the Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of the Set 4 | belushya guba
# Processing Record 48 of the Set 4 | ostrovnoy
# Processing Record 49 of the Set 4 | sentyabrskiy
# Processing Record 50 of the Set 4 | leningradskiy
# Processing Record 1 of the Set 5 | tessalit
# Processing Record 2 of the Set 5 | belmonte
# Processing Record 3 of the Set 5 | tuktoyaktuk
# Processing Record 4 of the Set 5 | mikhaylovka
# City not found. Skipping...
# Processing Record 5 of the Set 5 | dakar
# Processing Record 6 of the Set 5 | sai buri
# Processing Record 7 of the Set 5 | san patricio
# Processing Record 8 of the Set 5 | lorengau
# Processing Record 9 of the Set 5 | mafinga
# Processing Record 10 of the Set 5 | dwarka
# Processing Record 11 of the Set 5 | padang
# City not found. Skipping...
# Processing Record 12 of the Set 5 | aykhal
# Processing Record 13 of the Set 5 | san cristobal
# Processing Record 14 of the Set 5 | chokurdakh
# Processing Record 15 of the Set 5 | borgo san dalmazzo
# Processing Record 16 of the Set 5 | nome
# Processing Record 17 of the Set 5 | tual
# City not found. Skipping...
# Processing Record 18 of the Set 5 | gamba
# Processing Record 19 of the Set 5 | pisco
# Processing Record 20 of the Set 5 | nurobod
# Processing Record 21 of the Set 5 | alofi
# Processing Record 22 of the Set 5 | basqal
# Processing Record 23 of the Set 5 | nuuk
# City not found. Skipping...
# Processing Record 24 of the Set 5 | souillac
# City not found. Skipping...
# Processing Record 25 of the Set 5 | sur
# Processing Record 26 of the Set 5 | paciran
# City not found. Skipping...
# Processing Record 27 of the Set 5 | constitucion
# Processing Record 28 of the Set 5 | murray bridge
# Processing Record 29 of the Set 5 | olinda
# Processing Record 30 of the Set 5 | moree
# Processing Record 31 of the Set 5 | haverhill
# Processing Record 32 of the Set 5 | severo-kurilsk
# Processing Record 33 of the Set 5 | pemangkat
# City not found. Skipping...
# Processing Record 34 of the Set 5 | cockburn town
# Processing Record 35 of the Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 36 of the Set 5 | lebu
# Processing Record 37 of the Set 5 | terney
# Processing Record 38 of the Set 5 | asfi
# Processing Record 39 of the Set 5 | airai
# Processing Record 40 of the Set 5 | caravelas
# Processing Record 41 of the Set 5 | port alfred
# Processing Record 42 of the Set 5 | kavaratti
# Processing Record 43 of the Set 5 | saldanha
# Processing Record 44 of the Set 5 | avera
# Processing Record 45 of the Set 5 | banda aceh
# City not found. Skipping...
# Processing Record 46 of the Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of the Set 5 | hovd
# Processing Record 48 of the Set 5 | gorele
# Processing Record 49 of the Set 5 | paamiut
# City not found. Skipping...
# Processing Record 50 of the Set 5 | kikwit
# Processing Record 1 of the Set 6 | chadiza
# Processing Record 2 of the Set 6 | saskylakh
# Processing Record 3 of the Set 6 | tumannyy
# Processing Record 4 of the Set 6 | tutubigan
# Processing Record 5 of the Set 6 | vila franca do campo
# Processing Record 6 of the Set 6 | port macquarie
# Processing Record 7 of the Set 6 | jalingo
# Processing Record 8 of the Set 6 | tiksi
# Processing Record 9 of the Set 6 | la grande
# Processing Record 10 of the Set 6 | mount isa
# Processing Record 11 of the Set 6 | ketchikan
# Processing Record 12 of the Set 6 | halalo
# City not found. Skipping...
# Processing Record 13 of the Set 6 | conceicao do araguaia
# Processing Record 14 of the Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 15 of the Set 6 | cajabamba
# Processing Record 16 of the Set 6 | morant bay
# Processing Record 17 of the Set 6 | karamay
# Processing Record 18 of the Set 6 | cabo san lucas
# Processing Record 19 of the Set 6 | fortuna
# Processing Record 20 of the Set 6 | whitehorse
# Processing Record 21 of the Set 6 | attawapiskat
# Processing Record 22 of the Set 6 | prainha
# Processing Record 23 of the Set 6 | menongue
# Processing Record 24 of the Set 6 | vyazma
# Processing Record 25 of the Set 6 | tasiilaq
# City not found. Skipping...
# Processing Record 26 of the Set 6 | ust-kuyga
# Processing Record 27 of the Set 6 | shingu
# Processing Record 28 of the Set 6 | fairbanks
# Processing Record 29 of the Set 6 | saint-philippe
# Processing Record 30 of the Set 6 | carora
# Processing Record 31 of the Set 6 | luau
# Processing Record 32 of the Set 6 | barentsburg
# Processing Record 33 of the Set 6 | tolaga bay
# Processing Record 34 of the Set 6 | sao jose da coroa grande
# Processing Record 35 of the Set 6 | salamanca
# Processing Record 36 of the Set 6 | salvador
# Processing Record 37 of the Set 6 | quartz hill
# Processing Record 38 of the Set 6 | kysyl-syr
# Processing Record 39 of the Set 6 | te anau
# Processing Record 40 of the Set 6 | leh
# Processing Record 41 of the Set 6 | cervo
# Processing Record 42 of the Set 6 | hanzhong
# Processing Record 43 of the Set 6 | byron bay
# Processing Record 44 of the Set 6 | harper
# Processing Record 45 of the Set 6 | quatre cocos
# City not found. Skipping...
# Processing Record 46 of the Set 6 | tadine
# Processing Record 47 of the Set 6 | boende
# Processing Record 48 of the Set 6 | chernyshevskiy
# Processing Record 49 of the Set 6 | rehoboth
# Processing Record 50 of the Set 6 | cairns
# Processing Record 1 of the Set 7 | dzilam gonzalez
# Processing Record 2 of the Set 7 | taywarah
# Processing Record 3 of the Set 7 | victoria
# Processing Record 4 of the Set 7 | arbazh
# Processing Record 5 of the Set 7 | yuli
# Processing Record 6 of the Set 7 | mackenzie
# Processing Record 7 of the Set 7 | kudahuvadhoo
# Processing Record 8 of the Set 7 | waipawa
# Processing Record 9 of the Set 7 | srednekolymsk
# Processing Record 10 of the Set 7 | lata
# Processing Record 11 of the Set 7 | brae
# Processing Record 12 of the Set 7 | rapar
# Processing Record 13 of the Set 7 | hit
# Processing Record 14 of the Set 7 | atambua
# City not found. Skipping...
# Processing Record 15 of the Set 7 | komsomolskiy
# Processing Record 16 of the Set 7 | saint-augustin
# Processing Record 17 of the Set 7 | valreas
# Processing Record 18 of the Set 7 | dongli
# Processing Record 19 of the Set 7 | san quintin
# Processing Record 20 of the Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of the Set 7 | gladstone
# Processing Record 22 of the Set 7 | palu
# City not found. Skipping...
# Processing Record 23 of the Set 7 | samana
# Processing Record 24 of the Set 7 | yulara
# Processing Record 25 of the Set 7 | tulagi
# Processing Record 26 of the Set 7 | rawson
# Processing Record 27 of the Set 7 | aleksandrovskaya
# Processing Record 28 of the Set 7 | san miguel
# Processing Record 29 of the Set 7 | svrljig
# Processing Record 30 of the Set 7 | flin flon
# Processing Record 31 of the Set 7 | tocopilla
# Processing Record 32 of the Set 7 | perth
# Processing Record 33 of the Set 7 | puerto cabezas
# Processing Record 34 of the Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 35 of the Set 7 | esperance
# Processing Record 36 of the Set 7 | muscat
# Processing Record 37 of the Set 7 | aleksandrovka
# Processing Record 38 of the Set 7 | saint-joseph
# Processing Record 39 of the Set 7 | salisbury
# Processing Record 40 of the Set 7 | north platte
# Processing Record 41 of the Set 7 | gizo
# Processing Record 42 of the Set 7 | arman
# Processing Record 43 of the Set 7 | yar-sale
# Processing Record 44 of the Set 7 | bend
# Processing Record 45 of the Set 7 | sao filipe
# Processing Record 46 of the Set 7 | samarai
# Processing Record 47 of the Set 7 | chuy
# Processing Record 48 of the Set 7 | porbandar
# Processing Record 49 of the Set 7 | poum
# Processing Record 50 of the Set 7 | namatanai
# Processing Record 1 of the Set 8 | presidencia roque saenz pena
# Processing Record 2 of the Set 8 | santiago de cao
# Processing Record 3 of the Set 8 | straldza
# City not found. Skipping...
# Processing Record 4 of the Set 8 | hobyo
# Processing Record 5 of the Set 8 | serebryansk
# City not found. Skipping...
# Processing Record 6 of the Set 8 | parambu
# Processing Record 7 of the Set 8 | portland
# Processing Record 8 of the Set 8 | raudeberg
# Processing Record 9 of the Set 8 | the valley
# Processing Record 10 of the Set 8 | ahipara
# Processing Record 11 of the Set 8 | yeppoon
# Processing Record 12 of the Set 8 | saleaula
# Processing Record 13 of the Set 8 | gouyave
# Processing Record 14 of the Set 8 | hami
# Processing Record 15 of the Set 8 | phan rang
# City not found. Skipping...
# Processing Record 16 of the Set 8 | salalah
# Processing Record 17 of the Set 8 | tuatapere
# Processing Record 18 of the Set 8 | matay
# Processing Record 19 of the Set 8 | boyolangu
# City not found. Skipping...
# Processing Record 20 of the Set 8 | tubruq
# Processing Record 21 of the Set 8 | ca mau
# City not found. Skipping...
# Processing Record 22 of the Set 8 | gazanjyk
# Processing Record 23 of the Set 8 | meulaboh
# City not found. Skipping...
# Processing Record 24 of the Set 8 | puerto colombia
# City not found. Skipping...
# Processing Record 25 of the Set 8 | tuggurt
# Processing Record 26 of the Set 8 | kharan
# Processing Record 27 of the Set 8 | vestmanna
# Processing Record 28 of the Set 8 | nyrob
# Processing Record 29 of the Set 8 | haines junction
# Processing Record 30 of the Set 8 | malwan
# Processing Record 31 of the Set 8 | ipixuna
# Processing Record 32 of the Set 8 | kieta
# Processing Record 33 of the Set 8 | balabac
# Processing Record 34 of the Set 8 | grindavik
# Processing Record 35 of the Set 8 | prince rupert
# Processing Record 36 of the Set 8 | marcona
# Processing Record 37 of the Set 8 | pausesti
# Processing Record 38 of the Set 8 | chifeng
# Processing Record 39 of the Set 8 | luderitz
# Processing Record 40 of the Set 8 | hambantota
# Processing Record 41 of the Set 8 | sola
# Processing Record 42 of the Set 8 | coquimbo
# Processing Record 43 of the Set 8 | las vegas
# Processing Record 44 of the Set 8 | umm lajj
# Processing Record 45 of the Set 8 | bereda
# Processing Record 46 of the Set 8 | santa maria
# Processing Record 47 of the Set 8 | north bend
# Processing Record 48 of the Set 8 | derzhavinsk
# Processing Record 49 of the Set 8 | maniitsoq
# Processing Record 50 of the Set 8 | manokwari
# Processing Record 1 of the Set 9 | filingue
# Processing Record 2 of the Set 9 | bastia
# Processing Record 3 of the Set 9 | tomatlan
# Processing Record 4 of the Set 9 | cherskiy
# Processing Record 5 of the Set 9 | mahebourg
# City not found. Skipping...
# Processing Record 6 of the Set 9 | ateli
# Processing Record 7 of the Set 9 | champerico
# Processing Record 8 of the Set 9 | haibowan
# Processing Record 9 of the Set 9 | sobolevo
# Processing Record 10 of the Set 9 | chunoyar
# Processing Record 11 of the Set 9 | kambam
# Processing Record 12 of the Set 9 | westport
# Processing Record 13 of the Set 9 | luba
# Processing Record 14 of the Set 9 | sioux lookout
# Processing Record 15 of the Set 9 | clyde river
# Processing Record 16 of the Set 9 | roald
# Processing Record 17 of the Set 9 | huilong
# Processing Record 18 of the Set 9 | zachary
# Processing Record 19 of the Set 9 | wloclawek
# Processing Record 20 of the Set 9 | lushunkou
# Processing Record 21 of the Set 9 | comrat
# Processing Record 22 of the Set 9 | mundybash
# Processing Record 23 of the Set 9 | ambon
# Processing Record 24 of the Set 9 | vilcun
# Processing Record 25 of the Set 9 | sangar
# Processing Record 26 of the Set 9 | igrim
# Processing Record 27 of the Set 9 | nicolas bravo
# Processing Record 28 of the Set 9 | atar
# Processing Record 29 of the Set 9 | ndende
# Processing Record 30 of the Set 9 | zhigansk
# Processing Record 31 of the Set 9 | saint anthony
# Processing Record 32 of the Set 9 | marsh harbour
# Processing Record 33 of the Set 9 | umzimvubu
# Processing Record 34 of the Set 9 | dunedin
# Processing Record 35 of the Set 9 | coxim
# Processing Record 36 of the Set 9 | stornoway
# Processing Record 37 of the Set 9 | vila
# Processing Record 38 of the Set 9 | mukhanovo
# Processing Record 39 of the Set 9 | malanje
# Processing Record 40 of the Set 9 | bambanglipuro
# Processing Record 41 of the Set 9 | zonguldak
# Processing Record 42 of the Set 9 | buchanan
# Processing Record 43 of the Set 9 | fethiye
# Processing Record 44 of the Set 9 | kahului
# Processing Record 45 of the Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 46 of the Set 9 | bargal
# Processing Record 47 of the Set 9 | guiratinga
# Processing Record 48 of the Set 9 | malindi
# Processing Record 49 of the Set 9 | asyut
# Processing Record 50 of the Set 9 | asau
# Processing Record 1 of the Set 10 | yarada
# Processing Record 2 of the Set 10 | bahia blanca
# Processing Record 3 of the Set 10 | da nang
# City not found. Skipping...
# Processing Record 4 of the Set 10 | guthrie
# Processing Record 5 of the Set 10 | port hardy
# Processing Record 6 of the Set 10 | araceli
# Processing Record 7 of the Set 10 | liuzhou
# Processing Record 8 of the Set 10 | dolbeau
# Processing Record 9 of the Set 10 | suibara
# Processing Record 10 of the Set 10 | kalevala
# Processing Record 11 of the Set 10 | narsaq
# Processing Record 12 of the Set 10 | caernarfon
# Processing Record 13 of the Set 10 | iqaluit
# Processing Record 14 of the Set 10 | lakota
# Processing Record 15 of the Set 10 | suez
# Processing Record 16 of the Set 10 | corsicana
# Processing Record 17 of the Set 10 | swan hill
# Processing Record 18 of the Set 10 | djambala
# Processing Record 19 of the Set 10 | honiara
# Processing Record 20 of the Set 10 | ledec
# Processing Record 21 of the Set 10 | pacific grove
# Processing Record 22 of the Set 10 | hihya
# Processing Record 23 of the Set 10 | nioro
# Processing Record 24 of the Set 10 | vao
# Processing Record 25 of the Set 10 | aksu
# Processing Record 26 of the Set 10 | maragogi
# Processing Record 27 of the Set 10 | xinxiang
# Processing Record 28 of the Set 10 | ginda
# Processing Record 29 of the Set 10 | panjakent
# Processing Record 30 of the Set 10 | jimma
# Processing Record 31 of the Set 10 | hihifo
# Processing Record 32 of the Set 10 | porto novo
# Processing Record 33 of the Set 10 | kruisfontein
# Processing Record 34 of the Set 10 | chapais
# Processing Record 35 of the Set 10 | okandja
# Processing Record 36 of the Set 10 | adiake
# Processing Record 37 of the Set 10 | sisimiut
# Processing Record 38 of the Set 10 | semiletka
# Processing Record 39 of the Set 10 | eyl
# Processing Record 40 of the Set 10 | troitsko-pechorsk
# Processing Record 41 of the Set 10 | mankovo-kalitvenskoye
# Processing Record 42 of the Set 10 | banmo
# City not found. Skipping...
# Processing Record 43 of the Set 10 | olafsvik
# Processing Record 44 of the Set 10 | bambous virieux
# Processing Record 45 of the Set 10 | chengde
# Processing Record 46 of the Set 10 | calvinia
# Processing Record 47 of the Set 10 | temerloh
# Processing Record 48 of the Set 10 | muravlenko
# Processing Record 49 of the Set 10 | samarinda
# Processing Record 50 of the Set 10 | constitucion
# Processing Record 1 of the Set 11 | qasigiannguit
# Processing Record 2 of the Set 11 | trat
# Processing Record 3 of the Set 11 | cururupu
# Processing Record 4 of the Set 11 | port hedland
# Processing Record 5 of the Set 11 | port hueneme
# Processing Record 6 of the Set 11 | morondava
# City not found. Skipping...
# Processing Record 7 of the Set 11 | kushima
# Processing Record 8 of the Set 11 | la ronge
# Processing Record 9 of the Set 11 | vanavara
# Processing Record 10 of the Set 11 | nouadhibou
# Processing Record 11 of the Set 11 | kindu
# Processing Record 12 of the Set 11 | atasu
# Processing Record 13 of the Set 11 | leland
# Processing Record 14 of the Set 11 | emerald
# Processing Record 15 of the Set 11 | acari
# Processing Record 16 of the Set 11 | kuche
# Processing Record 17 of the Set 11 | beloha
# City not found. Skipping...
# Processing Record 18 of the Set 11 | osoyoos
# Processing Record 19 of the Set 11 | cooma
# Processing Record 20 of the Set 11 | sekoma
# Processing Record 21 of the Set 11 | lompoc
# Processing Record 22 of the Set 11 | kidal
# Processing Record 23 of the Set 11 | ugoofaaru
# Processing Record 24 of the Set 11 | milledgeville
# Processing Record 25 of the Set 11 | ormara
# Processing Record 26 of the Set 11 | grand forks
# Processing Record 27 of the Set 11 | manta
# Processing Record 28 of the Set 11 | mrirt
# Processing Record 29 of the Set 11 | finschhafen
# Processing Record 30 of the Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 31 of the Set 11 | chagda
# Processing Record 32 of the Set 11 | shkotovo-26
# Processing Record 33 of the Set 11 | hanstholm
# Processing Record 34 of the Set 11 | vanimo
# Processing Record 35 of the Set 11 | berezovyy
# Processing Record 36 of the Set 11 | humaita
# Processing Record 37 of the Set 11 | paka
# Processing Record 38 of the Set 11 | nikolsk
# Processing Record 39 of the Set 11 | camacha
# Processing Record 40 of the Set 11 | puerto del rosario
# Processing Record 41 of the Set 11 | krasnoselkup
# Processing Record 42 of the Set 11 | luanda
# Processing Record 43 of the Set 11 | tazovskiy
# Processing Record 44 of the Set 11 | igarape-miri
# Processing Record 45 of the Set 11 | saint-georges
# Processing Record 46 of the Set 11 | sao miguel do araguaia
# Processing Record 47 of the Set 11 | pacifica
# Processing Record 48 of the Set 11 | tianpeng
# Processing Record 49 of the Set 11 | maloyaz
# Processing Record 50 of the Set 11 | dingle
# Processing Record 1 of the Set 12 | naze
# Processing Record 2 of the Set 12 | santa fe
# Processing Record 3 of the Set 12 | muros
# Processing Record 4 of the Set 12 | udarnyy
# Processing Record 5 of the Set 12 | correntina
# Processing Record 6 of the Set 12 | la romana
# Processing Record 7 of the Set 12 | nouakchott
# Processing Record 8 of the Set 12 | perpignan
# Processing Record 9 of the Set 12 | valley station
# Processing Record 10 of the Set 12 | anjiang
# Processing Record 11 of the Set 12 | yangmei
# Processing Record 12 of the Set 12 | arauca
# Processing Record 13 of the Set 12 | norfolk
# Processing Record 14 of the Set 12 | safwah
# Processing Record 15 of the Set 12 | vicuna
# Processing Record 16 of the Set 12 | general roca
# Processing Record 17 of the Set 12 | brodokalmak
# Processing Record 18 of the Set 12 | khilok
# Processing Record 19 of the Set 12 | kalmunai
# Processing Record 20 of the Set 12 | bozeman
# Processing Record 21 of the Set 12 | kavieng
# Processing Record 22 of the Set 12 | alegrete
# Processing Record 23 of the Set 12 | kununurra
# Processing Record 24 of the Set 12 | samalaeulu
# Processing Record 25 of the Set 12 | segou
# Processing Record 26 of the Set 12 | najran
# Processing Record 27 of the Set 12 | benton harbor
# Processing Record 28 of the Set 12 | grand gaube
# Processing Record 29 of the Set 12 | tokamachi
# Processing Record 30 of the Set 12 | rivera
# Processing Record 31 of the Set 12 | faya
# Processing Record 32 of the Set 12 | shwebo
# City not found. Skipping...
# Processing Record 33 of the Set 12 | westpunt
# Processing Record 34 of the Set 12 | zaysan
# Processing Record 35 of the Set 12 | hualmay
# Processing Record 36 of the Set 12 | riyadh
# Processing Record 37 of the Set 12 | manzanillo
# Processing Record 38 of the Set 12 | along
# Processing Record 39 of the Set 12 | tsiroanomandidy
# City not found. Skipping...
# Processing Record 40 of the Set 12 | turka
# Processing Record 41 of the Set 12 | laukaa
# Processing Record 42 of the Set 12 | tezu
# Processing Record 43 of the Set 12 | honningsvag
# Processing Record 44 of the Set 12 | knysna
# Processing Record 45 of the Set 12 | grosseto
# Processing Record 46 of the Set 12 | inuvik
# Processing Record 47 of the Set 12 | sumbawa
# Processing Record 48 of the Set 12 | comines
# Processing Record 49 of the Set 12 | chengmai
# Processing Record 50 of the Set 12 | darab
# Processing Record 1 of the Set 13 | punta cardon
# Processing Record 2 of the Set 13 | regina
# Processing Record 3 of the Set 13 | samusu
# Processing Record 4 of the Set 13 | trinidad
# Processing Record 5 of the Set 13 | skalistyy
# Processing Record 6 of the Set 13 | wa
# City not found. Skipping...
# Processing Record 7 of the Set 13 | bathsheba
# Processing Record 8 of the Set 13 | north branch
# Processing Record 9 of the Set 13 | lubao
# Processing Record 10 of the Set 13 | santa lucia
# Processing Record 11 of the Set 13 | viesca
# Processing Record 12 of the Set 13 | mayo
# Processing Record 13 of the Set 13 | rantauprapat
# Processing Record 14 of the Set 13 | adrar
# Processing Record 15 of the Set 13 | tondano
# Processing Record 16 of the Set 13 | naron
# Processing Record 17 of the Set 13 | churapcha
# Processing Record 18 of the Set 13 | deputatskiy
# Processing Record 19 of the Set 13 | thunder bay
# Processing Record 20 of the Set 13 | egvekinot
# Processing Record 21 of the Set 13 | russell
# Processing Record 22 of the Set 13 | vostok
# Processing Record 23 of the Set 13 | lokomotivnyy
# Processing Record 24 of the Set 13 | eureka
# Processing Record 25 of the Set 13 | geraldton
# Processing Record 26 of the Set 13 | namibe
# Processing Record 27 of the Set 13 | rawannawi
# Processing Record 28 of the Set 13 | cabra
# Processing Record 29 of the Set 13 | belawan
# Processing Record 30 of the Set 13 | bima
# Processing Record 31 of the Set 13 | luganville
# Processing Record 32 of the Set 13 | gat
# Processing Record 33 of the Set 13 | binzhou
# Processing Record 34 of the Set 13 | santa isabel
# Processing Record 35 of the Set 13 | dawlatabad
# Processing Record 36 of the Set 13 | nador
# Processing Record 37 of the Set 13 | berlevag
# Processing Record 38 of the Set 13 | skjervoy
# Processing Record 39 of the Set 13 | chistogorskiy
# Processing Record 40 of the Set 13 | yabassi
# Processing Record 41 of the Set 13 | kipushi
# Processing Record 42 of the Set 13 | cap malheureux
# Processing Record 43 of the Set 13 | tidore
# Processing Record 44 of the Set 13 | jiddah
# Processing Record 45 of the Set 13 | gibara
# Processing Record 46 of the Set 13 | clarence town
# Processing Record 47 of the Set 13 | denia
# Processing Record 48 of the Set 13 | blitar
# Processing Record 49 of the Set 13 | atikokan
# Processing Record 50 of the Set 13 | zehdenick
# Processing Record 1 of the Set 14 | constantine
# Processing Record 2 of the Set 14 | laguna
# Processing Record 3 of the Set 14 | lianran
# Processing Record 4 of the Set 14 | ekhabi
# Processing Record 5 of the Set 14 | gulshat
# Processing Record 6 of the Set 14 | poopo
# Processing Record 7 of the Set 14 | aykino
# Processing Record 8 of the Set 14 | qaqortoq
# Processing Record 9 of the Set 14 | kiama
# Processing Record 10 of the Set 14 | tlyustenkhabl
# Processing Record 11 of the Set 14 | erzin
# Processing Record 12 of the Set 14 | chipinge
# Processing Record 13 of the Set 14 | kokopo
# Processing Record 14 of the Set 14 | si sa ket
# Processing Record 15 of the Set 14 | shubarshi
# Processing Record 16 of the Set 14 | bogandinskiy
# Processing Record 17 of the Set 14 | hirara
# Processing Record 18 of the Set 14 | gurupi
# Processing Record 19 of the Set 14 | bundaberg
# Processing Record 20 of the Set 14 | mporokoso
# Processing Record 21 of the Set 14 | acapulco
# Processing Record 22 of the Set 14 | sinnamary
# Processing Record 23 of the Set 14 | stutterheim
# Processing Record 24 of the Set 14 | virginia beach
# Processing Record 25 of the Set 14 | abu samrah
# Processing Record 26 of the Set 14 | aygut
# Processing Record 27 of the Set 14 | pachino
# Processing Record 28 of the Set 14 | tarrega
# Processing Record 29 of the Set 14 | erenhot
# Processing Record 30 of the Set 14 | vestmannaeyjar
# Processing Record 31 of the Set 14 | divnogorsk
# Processing Record 32 of the Set 14 | dzaoudzi
# Processing Record 33 of the Set 14 | eston
# Processing Record 34 of the Set 14 | boa vista
# Processing Record 35 of the Set 14 | kvarkeno
# Processing Record 36 of the Set 14 | vredendal
# Processing Record 37 of the Set 14 | palafrugell
# Processing Record 38 of the Set 14 | aksu
# Processing Record 39 of the Set 14 | garbolovo
# Processing Record 40 of the Set 14 | linguere
# Processing Record 41 of the Set 14 | florianopolis
# Processing Record 42 of the Set 14 | havre-saint-pierre
# Processing Record 43 of the Set 14 | hamilton
# Processing Record 44 of the Set 14 | san luis
# Processing Record 45 of the Set 14 | comodoro rivadavia
# Processing Record 46 of the Set 14 | harnosand
# Processing Record 47 of the Set 14 | katherine
# Processing Record 48 of the Set 14 | san pedro
# Processing Record 49 of the Set 14 | kirakira
# Processing Record 50 of the Set 14 | itaituba
# Processing Record 1 of the Set 15 | kamaishi
# Processing Record 2 of the Set 15 | fort nelson
# Processing Record 3 of the Set 15 | iracoubo
# Processing Record 4 of the Set 15 | tawkar
# Processing Record 5 of the Set 15 | hay river
# Processing Record 6 of the Set 15 | maceio
# Processing Record 7 of the Set 15 | ocean city
# Processing Record 8 of the Set 15 | sarai sidhu
# Processing Record 9 of the Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of the Set 15 | bolungarvik
# Processing Record 11 of the Set 15 | mao
# Processing Record 12 of the Set 15 | bintulu
# Processing Record 13 of the Set 15 | ballina
# Processing Record 14 of the Set 15 | berbera
# Processing Record 15 of the Set 15 | karauzyak
# Processing Record 16 of the Set 15 | lagos
# Processing Record 17 of the Set 15 | mahibadhoo
# Processing Record 18 of the Set 15 | batagay-alyta
# Processing Record 19 of the Set 15 | college
# Processing Record 20 of the Set 15 | santa isabel do rio negro
# Processing Record 21 of the Set 15 | stokmarknes
# Processing Record 22 of the Set 15 | pointe michel
# Processing Record 23 of the Set 15 | fare
# Processing Record 24 of the Set 15 | broome
# Processing Record 25 of the Set 15 | roma
# Processing Record 26 of the Set 15 | wanning
# Processing Record 27 of the Set 15 | yaan
# Processing Record 28 of the Set 15 | saint-francois
# Processing Record 29 of the Set 15 | ust-kut
# Processing Record 30 of the Set 15 | taltal
# Processing Record 31 of the Set 15 | thinadhoo
# Processing Record 32 of the Set 15 | wahiawa
# Processing Record 33 of the Set 15 | nombre de dios
# Processing Record 34 of the Set 15 | ocala
# Processing Record 35 of the Set 15 | necochea
# Processing Record 36 of the Set 15 | carutapera
# Processing Record 37 of the Set 15 | qingyuan
# Processing Record 38 of the Set 15 | stephenville crossing
# Processing Record 39 of the Set 15 | calama
# Processing Record 40 of the Set 15 | eldikan
# Processing Record 41 of the Set 15 | san juan
# Processing Record 42 of the Set 15 | daru
# Processing Record 43 of the Set 15 | amalapuram
# Processing Record 44 of the Set 15 | cocorna
# Processing Record 45 of the Set 15 | santa cruz de la palma
# Processing Record 46 of the Set 15 | lazaro cardenas
# Processing Record 47 of the Set 15 | shitanjing
# Processing Record 48 of the Set 15 | muriwai beach
# Processing Record 49 of the Set 15 | tinos
# Processing Record 50 of the Set 15 | macia
# Processing Record 1 of the Set 16 | isla mujeres
# Processing Record 2 of the Set 16 | half moon bay
# Processing Record 3 of the Set 16 | zolotkovo
# Processing Record 4 of the Set 16 | lubango
# Processing Record 5 of the Set 16 | omsukchan
# Processing Record 6 of the Set 16 | cape canaveral
# Processing Record 7 of the Set 16 | pandan
# Processing Record 8 of the Set 16 | ust-kamchatsk
# Processing Record 9 of the Set 16 | taksimo
# Processing Record 10 of the Set 16 | umm kaddadah
# Processing Record 11 of the Set 16 | suzhou
# Processing Record 12 of the Set 16 | shibarghan
# Processing Record 13 of the Set 16 | natchez
# Processing Record 14 of the Set 16 | gerash
# Processing Record 15 of the Set 16 | malvern
# Processing Record 16 of the Set 16 | esil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check number of cities in the dataframe
len(city_data)
# Out:
# 713

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.9258   18.4232     69.35        81          89
# 1     Havelock      US  34.8791  -76.9013     55.92        93           7
# 2       Touros      BR  -5.1989  -35.4608     77.20        86          47
# 3  Provideniya      RU  64.3833 -173.3000     26.71        80          75
# 4      Ushuaia      AR -54.8000  -68.3000     36.03        94          15
#
#    Wind Speed Current Description
# 0       13.49          light rain
# 1        5.37           clear sky
# 2        9.10    scattered clouds
# 3        8.95       broken clouds
# 4        3.71          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
